# %% [markdown]
# # Programación para *Data Science*

# %% [markdown]
# Unidad 8: Visualización de datos en Python
# ------------------------------------------------------
#
# ## Instrucciones de uso
#
# A continuación se presentarán explicaciones y ejemplos de generación de visualizaciones de datos en Python. Recordad que podéis ir ejecutando los ejemplos para obtener sus resultados.
#
# ## Introducción
#
# En módulos anteriores ya hemos visto cómo generar algunas visualizaciones básicas de datos con la librería [Matplotlib](https://matplotlib.org/). En este módulo nos centraremos en la generación de visualizaciones de datos más avanzadas. En primer lugar, veremos algunas funcionalidades de la librería [seaborn](https://seaborn.pydata.org/), que proporciona una interfaz de alto nivel a matplotlib con la que generar gráficas atractivas con pocas líneas de código. En segundo lugar, veremos cómo representar datos de redes en forma de grafos con la librería [Networkx](https://networkx.github.io/). Finalmente, veremos cómo podemos representar datos espaciales sobre mapas con la librería [geoplotlib](https://github.com/andrea-cuttone/geoplotlib).
#
# Además de las librerías que acabamos de mencionar, durante este módulo utilizaremos también las librerías que ya hemos ido presentando en los módulos anteriores: [NumPy](http://www.numpy.org/), [pandas](http://pandas.pydata.org/) y [scikit-learn](http://scikit-learn.org).
#
# ## Primeros pasos
#
# Para empezar, importamos las librerías que usaremos en este Notebook y que ya hemos presentado anteriormente.

# %%
# Importamos numpy, pandas, Matplotlib y los datasets de sklearn.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# Mostramos las gráficas en el notebook.
# %matplotlib inline

# %% [markdown]
# ## Gráficas con seaborn

# %% [markdown]
# En primer lugar, veremos algunos ejemplos de generación de gráficas con la librería [seaborn](https://seaborn.pydata.org/). Para ello, usaremos el conjunto de datos de flores Iris que ya hemos visto en módulos anteriores.

# %%
# Cargamos el dataset de Iris:
iris = datasets.load_iris()

# Guardamos los datos en la variable data.
data = iris.data

# Creamos un dataframe de pandas con los datos.
df = pd.DataFrame(data = np.c_[iris['data'], iris['target']], columns = iris['feature_names'] + ['target'])

# Mostramos las primeras 5 filas del dataframe.
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# La función [jointplot](http://seaborn.pydata.org/generated/seaborn.jointplot.html) permite crear una gráfica de dos variables, ofreciendo tanto información conjunta sobre las variables como marginal. La misma función puede ser utilizada para crear diferentes tipos de gráficas. Veamos algunos ejemplos.
#
# Para empezar, crearemos una gráfica de dispersión (en inglés, _scatter plot_) representando las muestras según las características del sépalo. Además, mostraremos histogramas marginales (que representarán la distribución de ambas características de manera individual).

# %%
# Importamos la librería seaborn.
import seaborn as sns

# Creamos un jointplot de tipo "scatter", indicando los nombres de las dos columnas
# que queremos utilizar como variables, el color y el tamaño de la figura.
g = sns.jointplot("sepal length (cm)", "sepal width (cm)", 
                  data=df, 
                  kind="scatter", 
                  space=0, color="g", size=10)

# %% [markdown]
# La gráfica de dispersión nos ofrece una primera aproximación a los datos: podemos ver cómo están distribuídas las muestras según la longitud y el ancho del sépalo.
#
# La función jointplot es muy versátil. Utilizando la misma función pero cambiando el tipo de gráfico a `hex`, podemos sustituir el diagrama de dispersión por un histograma conjunto usando intervalos (_bins_) hexagonales.

# %%
# Importamos la librería seaborn.
import seaborn as sns

# Creamos un jointplot de tipo "hex", indicando los nombres de las dos columnas
# que queremos utilizar como variables, el color y el tamaño de la figura.
g = sns.jointplot("sepal length (cm)", "sepal width (cm)", 
                  data=df, 
                  kind="hex", 
                  space=0, color="g", size=10)

# %% [markdown]
# El diagrama de tipo `hex` nos permite también ver la distribución de las muestras, omitiendo los efectos de pequeñas variaciones y focalizando, por lo tanto, en transmitir la información con una granularidad mayor.
#
# De manera análoga, podemos crear también un diagrama con una [estimación de la función de densidad](https://en.wikipedia.org/wiki/Kernel_density_estimation) (en inglés, _KDE_ o _Kernel density estimation_).

# %%
# Importamos la librería seaborn.
import seaborn as sns

# Creamos un jointplot de tipo "kde", indicando los nombres de las dos columnas
# que queremos utilizar como variables, el color y el tamaño de la figura.
g = sns.jointplot("sepal length (cm)", "sepal width (cm)", 
                  data=df, 
                  kind="kde", 
                  space=0, color="g", size=10)

# %% [markdown]
# Otra función muy útil de la librería seaborn es [pairplot](http://seaborn.pydata.org/generated/seaborn.pairplot.html), que crea una matriz de gráficas con las relaciones entre pares de variables del conjunto de datos.
#
# Así, para el conjunto de Iris que contiene cinco columnas (los cuatro atributos y la clase), pairplot generará una matriz de 5x5, mostrando diagramas de dispersión para cada par de variables. En la diagonal se muestra un histograma de los valores de la variable.

# %%
# Importamos la librería seaborn.
import seaborn as sns

# Generamos un pairplot coloreando las muestras según la clase a la que pertenecen
# y especificando una paleta de colores concreta.
sns.pairplot(df, hue="target", size=2, palette=sns.color_palette("husl", 3))

# %% [markdown]
# Esta visualización es muy útil para realizar una primera aproximación a los datos. Así, por ejemplo, si estuviéramos afrontando un problema de clasificación, podríamos tener una idea de qué atributos nos serán más útiles para la clasificación o de qué tipo de algoritmos nos servirían para afrontar el problema.
#
# Seaborn también nos permite generar mapas de calor o _heatmaps_. Por ejemplo, podemos calcular la correlación entre cada par de atributos de nuestro conjunto de datos y mostrarlo en un mapa de calor:

# %%
from string import letters
import seaborn as sns


sns.set(style="white")

# Calculamos la correlación entre atributos.
corr = df.corr()

# Generamos una máscara triangular (una matriz del mismo tamaño que la matriz
# de correlaciones, con valores False en el triángulo inferior y True en el resto).
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Generamos la figura matplotlib.
f, ax = plt.subplots(figsize=(11, 10))

# Creamos un mapa de colores.
cmap = sns.diverging_palette(255, 133, l=60, n=7, center="dark", as_cmap=True)

# Dibujamos el mapa de calor, utilizando como máscara la matriz mask y
# los colores especificados.
sns.heatmap(corr, mask=mask, cmap=cmap, 
            xticklabels=list(df), yticklabels=(list(df)),
            linewidths=.5, ax=ax)

# %% [markdown]
# Fijaos que hemos generado y aplicado una máscara para evitar que se muestren valores repetidos ya que la matriz de correlación es simétrica:

# %%
print mask
# Out:
# [[ True  True  True  True  True]
#  [False  True  True  True  True]
#  [False False  True  True  True]
#  [False False False  True  True]
#  [False False False False  True]]

# %% [markdown]
# ## Grafos con Networkx
#
# Podemos generar una representación gráfica de un grafo [Networkx](https://networkx.github.io/) con la función `draw`.

# %%
# Importamos la librería Networkx.
import networkx as nx

# Importamos el grafo del club de karate Zachary.
G = nx.karate_club_graph()

# Mostramos el grafo.
nx.draw(G)

# %% [markdown]
# Networkx permite ajustar la visualización del grafo, seleccionando los colores y tamaños de los nodos y aristas y decidiendo la posición de cada nodo en el plano en función de un algoritmo concreto. Vamos a generar una representación gráfica del grafo anterior que represente el grado de los nodos con el tamaño.

# %%
# Generamos una nueva figura.
plt.figure(1, figsize=(12, 10)) 

# Calculamos las posiciones de los nodos del grafo en el plano con el algoritmo
# spring.
graph_pos = nx.spring_layout(G)

# Calculamos el grado de los nodos del grafo.
d = nx.degree(G)

# Mostramos los nodos del grafo, especificando la posición, el tamaño (en función del grado), 
# el color y la transparencia.
nx.draw_networkx_nodes(G, graph_pos, 
                       node_size=[v * 150 for v in d.values()], 
                       node_color='blue', 
                       alpha=0.3)

# Mostramos las aristas del grafo, especificando la posición, 
# el color y la transparencia.
nx.draw_networkx_edges(G, graph_pos, edge_color='blue', alpha=0.3)

# Mostramos las etiquetas, indicando la fuente y el tamaño.
a = nx.draw_networkx_labels(G, graph_pos, font_size=12, font_family='sans-serif')

# %% [markdown]
# También podemos usar el color de los nodos para representar propiedades de los mismos. Por ejemplo, el color puede usarse para representar la comunidad a la que pertecen. La comunidad a la que pertenece cada nodo puede obtenerse de la ejecución de un algoritmo de [detección de comunidades](https://en.wikipedia.org/wiki/Community_structure).

# %%
# Importamos la librería de detección de comunidades.
import community

# Generamos una nueva figura.
plt.figure(1, figsize=(12, 10)) 

# Calculamos las posiciones de los nodos del grafo en el plano con el algoritmo
# spring.
graph_pos = nx.spring_layout(G)

# Detectamos las comunidades existentes en el grafo.
partition = community.best_partition(G)

# Definimos los colores que utilizaremos para los nodos.
colors = ['green', 'blue', 'red', 'orange', 'yellow', 'magenta', 'white']

# Para cada comunidad detectada, mostramos los nodos:
for count, com in enumerate(set(partition.values())):

    # Seleccionamos los nodos de la comunidad que estamos procesando.
    list_nodes = [nodes for nodes in partition.keys() 
                  if partition[nodes] == com]
    
    # Mostramos los nodos, coloreados según la comunidad a la que pertenecen.
    nx.draw_networkx_nodes(G, graph_pos, list_nodes, 
                           node_size = 800,
                           node_color = colors[count],
                           alpha = 0.5)

# Mostramos las aristas del grafo, especificando la posición, 
# el color y la transparencia.
nx.draw_networkx_edges(G, graph_pos, edge_color='k', alpha=0.3)

# Mostramos las etiquetas, indicando la fuente y el tamaño.
a = nx.draw_networkx_labels(G, graph_pos, font_size=12, font_family='sans-serif')

# %% [markdown]
# ## Mapas con geoplotlib

# %% [markdown]
# Veamos algunos ejemplos de visualización de datos sobre mapas.
#
# Primero, mostraremos un conjunto de puntos geoespaciales en un mapa.

# %%
# Importamos la librería geoplotlib.
import geoplotlib

# Cargamos el fichero bus.csv, que contiene coordenadas geográficas de paradas de autobuses.
data = geoplotlib.utils.read_csv('data/bus.csv')

# Mostramos los puntos del fichero directamente sobre un mapa en color azul.
geoplotlib.dot(data, color='b', point_size=0.75)

# Mostramos el mapa dentro del notebook.
geoplotlib.inline()
# Out:
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%0AIKA1tU6mzlLdVd3TPXLndvfOzuxu7e7J3EO4J3Bma2tjYzt6prurq7qqsiorJUVSgARIaCAAhFbu%0AHi7i/gggSBAgCJBQJH8vs7JKRrj4ISAC8I9/v1/f93fvtRAEQRCEAyiWy5RrNX752YcoirqvfZ4u%0ALnHn4WMun51gYnjopdvV6w3%2B6ZvvGB8a7jxWKJcolstkurpIJ%2BKEQyE28kWyuXXK1RqRUIhIKMB6%0Avsj5iTHGBgde%2B2Obn3vMmbNXkGWZu3e%2BZmLy0msf66Q4jk2tVsMya%2Bj%2BMKFgEFXTX7mf3bRYX1/G%0A55MZHTuLLMvYts3M9D36%2Boa3HUPX/ciyvH1/28Yw6iiKiiIr5MtV/tM//on/9//8NwD8%2Bss/Y1gm%0Af/uLn1Msl/lP//gn/pe/%2BTlWs8nC8iqP51f5v/zV52wUKvyPP3zL//Zv/4YHj6eZml1hoDeNbTvM%0ALa3xV1/cwPNA01RW19aZml3hb37%2BMUsrWcKhIAB//%2BX3/G//9m/44/d3sCybT29cwnFdFFnm4cwc%0Ay2s5vrh5mf/0j3/if/3bX1BrGISDAX7/zR2yuQL/6i8/YyNf4uGTeXq7U1i2w8LKGv/qLz/n3qNZ%0ADNN8rWPajst//93XnBkZxPFccvkSjuvyy88/AGB1bf2Qvgra5lfzxCNhfvHpDf7jP/yBSq2%2BY5v/%0A27/4S36cesz9mUWi4RCjAxlW1gtsFIoA9HZ30dcdR5FVcsUSi6vraJqGKksUKzV60kkGMikUWaVU%0AKTG/ksNxXBzX7TznOB6PZhfxvBae59GVShL0q5QqNQYyXTyaXSQSCtGdDLO8VmK4v5sni6vU6g38%0Ausb4YA/hUATTsljKbpAvVQiHggR0nX/2s4/59//9n2iYJoN93SSjER7NLhIK%2BMmkY4f6egrvh6Xs%0AKpfOTJDpSp/0UjrK1Rq/%2BeprkvE4P/uo/fNicWGGM2ev8vTJA3r7hl9xhNdjNy3qhkU8Fj2S4x9U%0A07ZpWiaW5RCJhtHU/f0O8ia2XufFxRnS6d4jP99pli%2BViYSCu77u5WoNx3EIB4PouvbG56rVqqiq%0AfijH2q9SucL86hq6enznBLDsJn3d3XQlY6yvLTM8cobHj%2B4yODR%2BrOvYr3K1ysz8EoZp8sXN6ye9%0AnGNRrzfwST6CgcBJL%2BWtkM0uMjw8iWWZlEsFYvHkvvZrGAa//fO3DPUNoCrb/84olssUyiXOjo2w%0AkS/RokUyFj%2BC1QuCIAjvGuWkFyAIgiC8HaymRcMwMSwTx3H46YfX9x1%2BASysrBIK%2BHn0dI6R/t6X%0A7hsKBXFcF9ezkaX2NslYHF3TqNUNshsbNG0HTVUIBQNk0mks22ZlPUd3MvVG4RfQuehw/sJ1zl%2B4%0Awcz0PYZHzrzRMY/L6so8jmMTiaaIxxMEgwM0GnVqtSqlUp5Wq4XP56NcLgDtEMvzPGy7CUC6q5/J%0AM5e3HTObXaS3fxT1uYtdM/MLLGXXuH7xEr3daRzXo2kZfH/vIYosc/V8%2B/Xy%2B3UuTQ7ik2Ranssv%0APvuEOw%2BmWF1fJx6LMjHch0/yYRh1hvrbFxWXsusk4wnOjg3iuU1GhwcBWC/WUBWJX352g1AwxNLq%0AMslEikQ8xvigC0Cr5bTPq%2BucHRtElkBVFSaG%2Bqg1DDZyORLxOKODvTiuiyRJnB9vh7HVWg2AT65f%0A4OGTeXRNY7CvB8dpkivVURWFX31%2Bk3gkjCz7uDg5/FrHlCSHs2ODtDwI%2BXX6z4/R291F07ZZWz/c%0A8AtAVxXW80UapsVf//RjHj%2Bd5/70HI7rEg2HaNo2qqqSK9UZH%2Brjo2sXefx0jmK5AsBPP7xMf2%2BG%0AlbUNVEXmzNgQf/r%2BLour69Rsh4%2BvXmB8uI/ltRwAH41dQZHvc39mkQ8uTXJ2bJj1fJFYOMDEcC//%0A8ddf4bguFyeH6EolUWSZYrnC/ek5zo4NMDrYz43L0GjUmJ5bpiuZ4Jef36Rar1OqVBnoG2JiuJd/%0A/3dfYpoW/d1xHMeladt8fPUCY0P9fPn9HUyrSToROfTXU3g/%2BHWd5bWNUxWAra7nURUFv/bswrwk%0ASQAc5d2MqqbjVhtHeIaD0VS1/T/dplqpEQ6Hjjwg2br5w2icntfhxLjeS0PHWCRM07ap1uoYpkk4%0AFDjQ74kvsiyHcPh4f45XG3UU2Xes5wRoNAwS0SDlUoHunn4AZPn0XqrZKBQJBYLoqkJ2I3eqflYe%0AFbPZJBYJnfQy3hp2s4kkyZRLBUIH%2BD4OBgKcHRthZn6Rkf7tf9MlYjEioQBPF5axHXvbzZKCIAiC%0AsJfT%2B1uVIAiCcKqs5XJomsr40CCZdOpAF5yatk0kFGbDKuK4LlNP5rh0dnLHduWawUZ%2BA13TkSUV%0Ax2mSL1WpNWrIsoIqy4SCAWKygizJqKqELMuEQwGunj9PLHw4d2X2D4zyaOoOZ89dZXjkDMtLT%2Bkf%0AGDuUYx%2BFfH4N06gzNn6hU5Xlui6NRh1d9xMMhoDMwY6ZW2d9fbld%2BfVC%2BDUzv0R/T4bVtfVtFUt%2B%0AXWVuaYVzYyOgQzjg56Orl2h5LrbdRJEVbl65gOd55Ap5Lp8Zo94wKFXq1I0mfT1pfJKMrMhcmhyl%0AUKljmBa9Pd2MDA7geR5ms8nS6jKO06JarZBKJBkfHqRSqbUfq1Xw611cmhylZphcGB/B9TzWNtqh%0AX7FUorenm0tnxvBrMpfOjFFrGJimiWmadKXTXJwcxWo2Ma3m5rk1fC0Xs2mRK5Y4PzGC9xrHtJ12%0AQHdxchQAz/No2g6r6xuYpvm6n/49pRNhytU6//nXX3L57AgXJsc4MzbMP/35FhuFIr3dXQCcGx%2Bi%0Ar7uLL7%2B7w%2BLKOoosM9zfw/BAP//513%2BkVK0SDYf417/qIl%2Bq4Xkteru7ODM2xP/43ddsFIpoqspQ%0AX4ZCxaQrmeDC5Di//%2BYWq%2BsFgn4///KXn5NKxFjLFYhFo1SqNf7xT99jWu0ANhYJ02jU%2BLsvf6BW%0Ab19o/puf3WRxNcuX3/0IwM8%2Bvtb52BzXJR6N03Qc/vqnH%2BHz%2BfjPv/kjpmkxkEkRCweP5DUV3n3p%0ARJLpuVkGejP0pBIH2teymqysr7eD30iU3u4UsUj4tdZRrzco1WrMzC9Sq9cJBgLo%2BtFXPO3Gcew3%0ACjMOm6aqxGJhyuX2jQZHFYLValVSyW4AJOn4g5HTpF5voGh7fw1oqkoqEadhGJTLNWKx8Gt93TRt%0AG07g9V5ZyxGLHH%2B1Y4sWiqJSqRTJ9A6ysZElmeo%2B9nXsl9VsIksqiqKxuv5%2BBGB4rVP1M/Bt0WhU%0A9139tWVieIj1fJGNfJ6uVGrbc4qiMdTXh%2B24h7lMQRAE4R0nAjBBEARhX1KJBMVymeH%2Bg7f/0VSV%0ADy6dJ58v8uWt2yytbfBkcYlELIYqK9SNBnXDQJFldE0jFY%2BTKxYoV6uMDw1zM3OOUOj4LmYrikpX%0Adz9zs48ZGT1Dd3c/G%2BsrdHX3Hdsa9mt%2B7jH9A6MMDo7hui5zs48xjDqBQIhAIMSG2aDZNPE8D1lW%0AicaShMORzVCszXVdXMfBtAyMRp1CYZ1UundH5Vu93uDR0zmG%2B3pRXmhLAiBLKpFwmHvTT/jg0vlO%0AZdkWx3VwXIel7DoPpmcY6uvvPGfbNo%2Bezu7ayqRare76sRtmk6XV7PZzOK1XthHc6/mN ...

# %% [markdown]
# Nota: Si el mapa no se carga correctamente, volved a ejecutar el código una segunda vez.

# %% [markdown]
# Fijaos que el fichero de datos contiene tres atributos: dos de ellos nos indican la posición geográfica (latitud y longitud) y el tercero contiene el nombre. Los dos primeros atributos (`lat` y `lon`) son utilizados por geoplotlib para saber en qué lugar del mapa se debe mostrar el punto que representa cada muestra.

# %%
# Mostramos un resumen de los datos.
print data

# Mostramos la primera muestra como ejemplo.
print data.head(1).values()
# Out:
# DataAccessObject(['lat', 'lon', 'name'] x 30057)
# [array([ 55.74393347]), array([ 12.4939206]), array(['R\xc3\xa5dhuspassagen'],
#       dtype='|S55')]

# %% [markdown]
# Con geoplotlib se pueden generar también mapas interactivos. Vamos a generar la misma visualización que en el ejemplo anterior en modo interactivo.

# %%
# Importamos la librería geoplotlib.
import geoplotlib

# Cargamos el fichero bus.csv, que contiene coordenadas geográficas de paradas de autobuses.
data = geoplotlib.utils.read_csv('data/bus.csv')

# Mostramos los puntos del fichero directamente sobre un mapa en color azul.
geoplotlib.dot(data, color='b', point_size=0.75)

# Mostramos el mapa de manera interactiva.
geoplotlib.show()

# %% [markdown]
# Notad que la única diferencia es la última instrucción, en la que indicamos el modo de visualización.
#
# En la visualización interactiva podemos utilizar la ruedecilla del ratón o las teclas `i`/`o` para ajustar el zoom de la imagen y mover el ratón dejando el botón izquierdo pulsado o las teclas `a`/`d`/`w`/`s` para mover la visualización.

# %% [markdown]
# En segundo lugar, representaremos un grafo en el cual los nodos se encuentran geoposicionados.

# %%
# Importamos la librería geoplotlib.
import geoplotlib

# Cargamos el fichero flights.csv, que contiene datos sobre vuelos.
data = geoplotlib.utils.read_csv('data/flights.csv')

# Mostramos el grafo proyectado sobre el mapa, indicando los atributos que informan
# de la longitud y latitud del nodo de origen y destino para cada arista.
geoplotlib.graph(data,
                 src_lat='lat_departure',
                 src_lon='lon_departure',
                 dest_lat='lat_arrival',
                 dest_lon='lon_arrival',
                 color='afmhot_r',
                 alpha=16,
                 linewidth=2)

# Mostramos el mapa dentro del notebook.
geoplotlib.inline()
# Out:
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%2BF5SRCgi%0ANCMxC4PNYMAYj%2BXMXVnd1bu71%2Bo/%2BXzqdd5z3t2VtSuzPAIGzGAzjxIKTTE9IfUHGRlZYp5scf3W%0AqlWJFBF6BJYQccV93z4AFRARERERERERERERERG1CP9tL4CIiIiIiIiIiIiIiIjoKjEAIyIiIiIi%0AIiIiIiIiopbCAIyIiIiIiIiIiIiIiIhaCgMwIiIiIiIiIiIiIiIiaikMwIiIiIiIiIiIiIiIiKil%0AMAAjIiIiIiIiIiIiIiKilsIAjIiIiIiIiIiIiIiIiFoKAzAiIiIiIiIiIiIiIiJqKQzAiIiIiIiI%0AiIiIiIiIqKUwACMiIiIiIiIiIiIiIqKWwgCMiIiIiIiIiIiIiIiIWgoDMCIiIiIiIiIiIiIiImop%0ADMCIiIiIiIiIiIiIiIiopTAAIyIiIiIiIiIiIiIiopbCAIyIiIiIiIiIiIiIiIhaCgMwIiIiIiIi%0AIiIiIiIiaikMwIiIiIiIiIiIiIiIiKilMAAjIiIiIiIiIiIiIiKilsIAjIiIiIiIiIiIiIiIiFoK%0AAzAiIiIiIiIiIiIiIiJqKQzAiIiIiIiIiIiIiIiIqKUwACMiIiIiIiIiIiIiIqKWwgCMiIiIiIiI%0AiIiIiIiIWgoDMCIiIiIiIiIiIiIiImopDMCIiIiIiIiIiIiIiIiopTAAIyIiIiIiIiIiIiIiopbC%0AAIyIiIiIiIiIiIiIiIhaCgMwIiIiIiIiIiIiIiIiaikMwIiIiIiIiIiIiIiIiKilMAAjIiIiIiIi%0AIiIiIiKilsIAjIiIiIiIiIiIiIiIiFoKAzAiIiIiIiIiIiIiIiJqKQzAiIiIiIiIiIiIiIiIqKUw%0AACMiIiIiIiIiIiIiIqKWwgCMiIiIiIiIiIiIiIiIWgoDMCIiIiIiIiIiIiIiImopDMCIiIiIiIiI%0AiIiIiIiopTAAIyIiIiIiIiIiIiIiopbCAIyIiIiIiIiIiIiIiIhaCgMwIiIiIiIiIiIiIiIiaikM%0AwIiIiIiIiIiIiIiIiKilMAAjIiIiIiIiIiIiIiKilsIAjIiIiIiIiIiIiIiIiFoKAzAiIiIiIiIi%0AIiIiIiJqKQzAiIiIiIiIiIiIiIiIqKUwACMiIiIiIiIiIiIiIqKWwgCMiIiIiIiIiIiIiIiIWgoD%0AMCIiIiIiIiIiIiIiImopDMCIiIiIiIiIiIiIiIiopTAAIyIiIiIiIiIiIiIiopbCAIyIiIiIiIiI%0AiIiIiIhaCgMwIiIiIiIiIiIiIiIiaikMwIiIiIiIiIiIiIiIiKilMAAjIiIiIiIiIiIiIiKilsIA%0AjIiIiIiIiIiIiIiIiFoKAzAiIiIiIiIiIiIiIiJqKQzAiIiIiIiIiIiIiIiIqKUwACMiIiIiIiIi%0AIiIiIqKWwgCMiIiIiIiIiIiIiIiIWgoDMCIiIiIiIiIiIiIiImopDMCIiIiIiIiIiIiIiIiopTAA%0AIyIiIiIiIiIiIiIiopbCAIyIiIiIiIiIiIiIiIhaCgMwIiIiIiIiIiIiIiIiaikMwIiIiIiIiIiI%0AiIiIiKilMAAjIiIiIiIiIiIiIiKilsIAjIiIiIiIiIiIiIiIiFqKfNsLICK6q15/mL7tJRARERER%0AERHRNXv55PFtL4GI6E5iBRgRERERERERERERERG1FAZgRERERERERERERERE1FIYgBERERERERER%0AEREREVFLYQBGRERERERERERERERELYUBGBEREREREREREREREbUUBmBERERERERERERERETUUhiA%0AERERERERERERERERUUthAEZEREREREREREREREQthQEYERERERERERERERERtRQGYERERERERERE%0ARERERNRSGIARERERERERERERERFRS2EARkRERERERERERERERC2FARgRERERERERERERERG1FAZg%0ARERERERERERERERE1FIYgBEREREREREREREREVFLYQBGRERERERERERERERELYUBGBERERERERER%0AEREREbUUBmBERERERERERERERETUUhiAERERERERERERERERUUthAEZEREREREREREREREQthQEY%0AERERERERERERERERtRQGYERERERERERERERERNRSGIARERERERERERERERFRS2EARkRERERERERE%0ARERERC2FARgRERERERERERERERG1FAZgRERERERERERERERE1FIYgBEREREREREREREREVFLYQBG%0ARERERERERERERERELYUBGBEREREREREREREREbUUBmBERERERERERERERETUUhiAERERERERERER%0AERERUUthAEZEREREREREREREREQthQEYERERERERERERERERtRQGYERERERERERERERERNRSGIAR%0AERERERERERERERFRS2EARkRERERERERERERERC2FARgRERERERERERERERG1FAZgRERERERERERE%0ARERE1FIYgBEREREREREREREREVFLYQBGRERERERERERERERELUW%2B7QUQEREREdHNEp5AvlBsep/f%0A70MoGIQs8U8FIiIiIiIi%2Bnnxr1oiIiIiohblCgf5YgkAEArqUBUVB4aBtlgMLyfHm%2B5TLlews7%2BP%0AvUwG5bIP0XD4JpdMREREREREdCUYgBERERERtQgjnwMA%2BP1%2ByLKEWCSMsaEHUGQZMwuLKJolPB1/%0AiKCunXicgVQvBlK9MPIFfFxYRjCoQVXUm3gKRERERERERFfCB6By24sgIrqLXn%2BYvu0lEBFRC0hn%0AM/D5/JAlGaGgiomR4St/jLmlFZQsC0Ht5OCMiIiIiBq9fPL4tpdARHQnsQKMiIiIiOgnlS8WMDY0%0AiGQ8hkKxBFm%2Bno/3Y0MDmJpfgGlb0FWGYERERERERPTj89/2AoiIiIiI6HyEJ5DOZgBUkIzHAADh%0AUBCaGri2x5wcHUFnsg2mbSKdzaBkWdf2WERERERERESXxQowIiIiIqKfjJHP4Zenk1CuqeLrOKmu%0ATqS6OgEA6ayBxS%2BrCOoaFPn6gjciIiIiIiKii2AFGBERERHRD8x2beym9yE8UXf7TYdf30vGY/j1%0A2SQUOYBcoXCrayEiIiIiIiL6HgMwIiIiIqJb5grn2PuKJRN/ffEUPl8FtmsDAAJKAIVi6aaWd6Kx%0AoQEMDfThwDBueylERERERERENQzAiIiIiIhu0YFhQNdUuMJBxsjWhWG2ayPV1QFFljExMgzLqgZg%0AmhrAbiZzW0tukIzHEA7pDVVqRERERERERLeFM8CIiIiIiG5JOpvB44cjiEXCtdv%2B%2BeYd2mLVmVrF%0AkomnYw9r902OjuDtx1kk4wls76XRmUggHAre%2BLpNy0LJslEoFlEolVAyLfj9EkL6za%2BFiIiIiIiI%0AqBkGYEREREREN8wVDvLFEl5MjEPXtLr7%2BlO92E0fwO/3IdXVUXdfUNfw6sljvJ6eQSLWhg/zC/jt%0AxdNrWWPJtJAvFpEvFmFaNhxXwHFclCseFDkAWZYRUGTIkoJISKnuY1nI5XPo7ui8ljURERERERER%0AnRUDMCIiIiI6N%2BEJOK5ApVKuVf0IT8C0LDiuA03VWA10jAPjAL1dnZgcHWl6f6qrE9lcDukDo676%0A61BAUfBoeBifPq9cy/o2dnbxZX0DpmVDliQEAoHazzOkN9/nMNAbSPWgq70N%2BwdZqIp6LesjIiIi%0AIiIiOgsGYERERERUR3gCsnT8x8SMkUVnsg09ne04MAyYlo1coYCu9iT6e7sRDYfw76npG1z ...

# %% [markdown]
# En este caso, cada una de las filas del fichero 'flights.csv' representa una de las aristas del grafo, que queda determinada por la posición del nodo de origen (`lat_departure` y `lon_departure`) y del nodo de destino (`lat_arrival` y `lon_arrival`).

# %%
# Mostramos un resumen de los datos.
print data

# Mostramos la primera muestra como ejemplo.
print data.head(1).values()
# Out:
# DataAccessObject(['lon_arrival', 'lat_departure', 'lat_arrival', 'lon_departure'] x 57859)
# [array([ 38.51]), array([ 55.509]), array([ 55.681]), array([ 61.838])]

# %% [markdown]
# En tercer lugar, veremos cómo podemos delimitar zonas en mapas y generar visualizaciones que aprovechen estas zonas. En concreto, generaremos un mapa de los Estados Unidos, coloreando los condados según el ratio de desempleo de los mismos.

# %%
# Importamos las librerías geoplotlib y json.
import geoplotlib
import json

# Definimos la función get_color, que devuelve el color en el que debe pintarse
# cada condado según la tasa de desempleo (almacenada en la variable unemployment)
# y el mapa de colores elegido (almacenado en la variable cmap).
def get_color(properties):
    key = str(int(properties['STATE'])) + properties['COUNTY']
    if key in unemployment:
        return cmap.to_color(unemployment.get(key), .15, 'lin')
    else:
        return [0, 0, 0, 0]

# Abrimos y cargamos el fichero unemployment.json.
with open('data/unemployment.json') as fin:
    unemployment = json.load(fin)

# Seleccionamos un mapa de color.
cmap = geoplotlib.colors.ColorMap('Blues', alpha=255, levels=10)

# Dibujamos los polígonos que delimitan los condados, pintándolos según nos indique la función
# get_color.
geoplotlib.geojson('data/gz_2010_us_050_00_20m.json', 
                   fill=True, 
                   color=get_color, 
                   f_tooltip=lambda properties: properties['NAME'])

# Pintamos los perímetros de los polígonos de color blanco.
geoplotlib.geojson('data/gz_2010_us_050_00_20m.json', 
                   fill=False, 
                   color=[255, 255, 255, 64])

# Fijamos la visualización a los Estados Unidos.
geoplotlib.set_bbox(geoplotlib.utils.BoundingBox.USA)

# Mostramos el mapa dentro del notebook.
geoplotlib.inline()
# Out:
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%0A%2B45CYSEAEiAJ7tshefZz7%2B3brb7d6tYy4x7NjDxLWGF7HKOxx54J2eHwzFgxirDDCjlsT4xHGmlC%0AI4U8UrfULbV679v3np3ncCcIEACx74Xa96zcCv6jgCJBgiRIorAxn4gTB6xcvq%2BqsjK/7/u97%2B%2B1%0A3RkaXuMZFhMrdMSiHO/rxSFJz27eRKFUZiWZQRRtuGQZSZKQHQ4CPu%2Bm/XTDQBLF515Tahozi4tM%0Azy8CIIkCgiA09zWMOvFYGKfDRb5UxDAMCuUSvR3dnDh2BIckoRsG3959wNpaHaWm8qMPriE7HKia%0AxsTMHMlsjoDPR1d7G/G26EvfTyKVplqrcexI90v3exZV07hx7wEBn49Lpwdf61gLizdlbGoOgFyh%0AwNXzpxDFl/9e94p8RWWlaHCqw/PW58rlC7hcLpyyYwd6ZrHfqFQUJEnE4dif1/LbkMsXGJmcxi7Y%0AuTh4ArfLtdddstiHaJqOYRrv/PXx9e17REPhbe%2BfzmX5%2BL1LLexRg%2B32a7C/F4BsvkCxUsUwdFRN%0AI%2Bjz0xWPtbSP2XyBcDDQ0jZ2GlXTGBp7jM/jQ9U1KoqCYRhcPj2I1%2BNu7lcolUlls/R0drxyjvIq%0AdMNgaTVFKpNBEiXibZFXzhPedaqKwt2RMQK%2BAIVSgb7uTtrCIWRHY0yWzRdYSCS5MHh8j3tqYbE/%0AOIj3Y4u3487wKB5X47mlqCqpTJr2tjbsNjh38nDdG3XD4O7wKJFQgIHenlfu/9NvvqNer3PyWB8A%0Ay6tpQoEAyWyGdKZAMODBMAzq9TV%2B%2BMHV5rOlVRRKJUYmpvF7ffg8Tnq7OlvanoWFxRN0w%2BAPPv%2BK%0Aer3OiaO9pLNF2qORve7WtpldXOLsyQFqao2KolIql7l67gxyC9YpE%2Bk0Y5MzxNtaO4c87IhbvdgR%0Ai1JVajwYHefq%2BbMvPUHA58UhiZQqVQB0XWduaZlSpcrpgWNMLyxRr9c5NXCMyDODP0kUkbwiFwZP%0AcKKvh0KpzOTcAvlikYDPR71eJxpvLDLkS0XKlQrnB09Qr9dJZ3NMzy9T0xTKFYXerk76ujrIFYv8%0A9NvvkCUHA3299HR1cfY1BhrVWg2307nt/aEhmt1/9BhJEnBIW36kFhYtQRRtGMYaDoe0b8UvAK9s%0AJ6%2BYGIb%2B1v0MBQPk8gWcsoNiqYxpmgAIgoD/GeHdwmI/EQoGdmWB3uKAY7OxVt/rTuw9rtcci9nt%0AdpRa7bWPe13sdvsr98kXc0BDAAsHA9bi5zaQHQ4Mw2j8LTmQJQeGYVIolZsCmG4YPByfwG6309PZ%0A8cZtZfMF5pZWUFQVv8eHz%2BOjVClZ4tc2cLtcXL94jtV0hv6ejueE%2BlZd74IgIooidrsAQL1uYhgG%0Aptm4ZiRJxm63rW9bQ9fVFx77KgzDQNfVTcdtvPZ0W0/3ZaPdet3ENI1N%2Bzx97Kveh4WFxZuTyubI%0A5IrUNAXdMAj5/RjGGtlCvrlPvV4n3hZ5TqwpV6qbgi3eBqVWawpgmqbikCQyuRw/%2BuDajpx/PyGJ%0AItcvntv2/n3dnYT8fkRR4MHoY0RRRNU1fB43n1693Nzv27sPWi5%2BAQR8PgS7HbNuohvWfdjCYjeR%0ARJELpwa5N/KImqrTHo1QqlTwed4%2BaL7VVJQqRzpjdLc4qBEaQv3D8UmOxN987mPRYEu1RrBL%2BDwS%0Ai4mVbZ3E5XRuWnDoirdz79EYtx%2BOcPp4/7ayqTbO4XW7KVcbYtr4zByrmTS6riNJEqVKlYWV1eZE%0Ao83r5eiRjk0PR1XViIXDKKpGX9frXyBKrUa9vv2VJ1XTuP/oMXY7uJ0uThzte%2B02LSzeFLvdjmbo%0AiOL%2BFl5FUaLDb5Aqm3QE316o83ndJFJpAl5PU/RSdYNiqWyJYBYWFgcahySi1mp73Y09Z6D3CJNz%0AC81FpFcRDgR5MDrG%2B5cutqxPSq32SgFM1TX6ul/PRcCiwXvnzzIyMQlrNpyyE1EUmFlcIhoOIjsc%0AjExMEg2FSeeyb5T9pdRqjE3NUl9bw%2BNy43K6SOeyyA6J84MnWvCODieSKNIdb9%2BVtgRBxOGQAcgW%0AiswtNBxDeo90Ew74ARlNUxFFkbnFJVS9zomjRwCaopPDIZPO5kllM/i9Porl0kvac3Di6BHqdROH%0AQ2YpkaRYLnFqoL85/9xoq7p%2BnxYFG26Xdz2zU8Q0JQTB/lx/NsbqL3sflhBmYfHmiEJDWF5eTWEY%0AdVZWMxzp7CAcCDb3Seeym7J8RiYmyeQKnDjauyMCmKppzXGCYZq4XU7q9TUEQdjSEeldIxaJ4Pd6%0A%2BN2ffgHAjz64ys2hYT55SvwCmhliu4HdLiBLDpaTaY50xHdFeLOwsGjQEY1wD3DKDf2hLXIwMsBK%0A5TInek/tSlvj0/OW%2BLVDvPQJ7HG5uTU0zIVTJ7c10awqCvPLSRLpJLlCiWvnz9D1mhMkr8fdHHx4%0A3U/%2BXkqsMgksr67S2d7eXBDJFYqUq1UKpQqFUmNC89GVi6SzuZe2k0ilWVpNcaSjnVikkWWWyRdY%0ASiQ5c7y/uV%2BuWCSTy78wpXtybh67HY71dG8r7dvCYieRJQdldOoHYMLcHRR5sFSjzSu8dRaYKErP%0ARWrLkki1sjNZZhYWFhZ7iZUA1nAYUDVt2wIYNDIzJufmWzYeczmdrxUkZfF6SKLIxVODLCWSzC2v%0A4HG7iYbCPJqYJhQMNDMjve7tXRO6YXB/dIxKRaGiKAR8vi3tK1/ldmGxN2yIX/limf/hf/pthkYn%0ANm1/78IZ/uq/8ecJ%2BhuBT//i9/%2BModEJ/rd/7d/m0tnTzWwsgBt3H/Ivfu9P%2BMGH7/H5t7df2GZ3%0AR4z/%2Bm/89aZY9f/8e/%2BYdDbP//U/%2B1/T292Fpqmb2nqaoN/Hv/OXf8K19WyIf/H7f8byaoq//V/8%0AHxBFcVvvQ9OwRDALizckFPATCvibFsQjE5MI9idzwmK5zJGOdiRRRDcMbtx9AEB3R/uOZQAvrCSa%0Aglu%2BWMDldOJ0OllJrjaCut9xAczv9TC3tMwHl8/TFg4B8MnVy899Ls86R7WSWCRIqVLDbrNRLFeY%0AWXrM8Z4eQgH/rvXBwuJdQlFq3Lg/xFodBMGGz%2BNhcm6B3s4uZGn/C9CG0QiI8rU48D6dyZHOF8kW%0A8vi9VpD/TvDSJ3AoEKCiVLn98BEfXr4ANLz3N%2Bp7FUplFpZXcDplFhOrlMoVbDYbDklCFOwIwvas%0AJl7E01E4XfF2uuLtzC6tMDz%2BmI5YjMm5Wcz1hQhRFPB5vFSrNYbGHhMK%2BEmk0pim%2BZwIl8xkuf1w%0ABL/Pt6lWWa5QQFFVAj5f87VCqUI6V2Cgt5FWv/GgBrj3aIzZxWVCAR%2BdsbbXfn/JTBabzbbpnBYW%0Ar4NmNK7/jZvwfkYUJdwOjbJaJ9iisf%2BGPWLIspuysNjXbFid7ffs1b2ibu7/e/pusB27wafxuNxU%0AFJV7I2NcOtOaeqxPR5JvhSw5mFlYsuz03oKueIx0voBga8wjJNFBJpfH43KjGxqd7dsbc0uiyNVz%0AZymWK0zMzqPUamQLeWqqSiwcRRQFgr4AiVTa%2Br72IQ6HjKJU%2BK/%2B9n%2BLpuv81X/zVzg10AhSfDg2%0Aze/8wZ/yN//Of8ff%2Bj/%2BJ7icTxZM/vt/8jv8zf%2B8k2g4iKJsFpN%2B8ZOr/PDD9wBYTWf5b//hb/Kr%0 ...

# %% [markdown]
# Fijaos que en este caso hemos usado datos de dos ficheros diferentes para realizar la visualización. Por un lado, el fichero `gz_2010_us_050_00_20m.json` contiene la definición de los polígonos que delimitan los condados. Por otro lado, el fichero `unemployment.json` incluye el ratio de desempleo de cada condado, que hemos usado para colorear el mapa.
#
# Cuando hemos dibujado los polígonos rellenos de color, hemos especificado el parámetro `f_tooltip`. Este parámetro permite definir la información que se mostrará en el mapa interactivo cuando pasemos el ratón por encima de la zona. Veámoslo generando una visualización interactiva del mismo mapa.

# %%
# Dibujamos los polígonos que delimitan los condados, pintándolos según nos indique la función
# get_color.
geoplotlib.geojson('data/gz_2010_us_050_00_20m.json', 
                   fill=True, 
                   color=get_color, 
                   f_tooltip=lambda properties: properties['NAME'])

# Pintamos los perímetros de los polígonos de color blanco.
geoplotlib.geojson('data/gz_2010_us_050_00_20m.json', 
                   fill=False, 
                   color=[255, 255, 255, 64])

# Fijamos la visualización a los Estados Unidos.
geoplotlib.set_bbox(geoplotlib.utils.BoundingBox.USA)

# Mostramos el mapa interactivo.
geoplotlib.show()
